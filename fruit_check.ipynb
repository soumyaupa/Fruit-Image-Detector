# %%
import numpy as np
import cv2
import glob
from keras.layers import Dropout, Dense, Flatten
from keras.models import Model
from keras import applications
import matplotlib.pyplot as plt
#importations
# Out:
# Using TensorFlow backend.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\hp\Anaconda3\lib\site-packages\tensorflow_core\python\pywrap_tensorflow.py", line 58, in <module>
#     from tensorflow.python.pywrap_tensorflow_internal import *
#   File "C:\Users\hp\Anaconda3\lib\site-packages\tensorflow_core\python\pywrap_tensorflow_internal.py", line 28, in <module>
#     _pywrap_tensorflow_internal = swig_import_helper()
#   File "C:\Users\hp\Anaconda3\lib\site-packages\tensorflow_core\python\pywrap_tensorflow_internal.py", line 24, in swig_import_helper
#     _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#   File "C:\Users\hp\Anaconda3\lib\imp.py", line 242, in load_module
#     return load_dynamic(name, filename, file)
# ...

# %%
def pre_trained(trainable, dim):  # trainable is a boolean
    # create a pre-trained model (VGG16)
    # trainable: TRUE/ FALSE
    #   TRUE means the last five layers are trainable
    #   FALSE means non of the layers are trainable
    model = applications.VGG16(weights="imagenet", include_top=False, input_shape=(dim, dim, 3))
    if not trainable:
        for layer in model.layers[:]:
            layer.trainable = False
    else:
        for layer in model.layers[:-5]:
            layer.trainable = False
    x = model.output
    x = Dropout(0.2)(x)
    x = Flatten()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.2)(x)
    x = Dense(22, activation='softmax')(x)
    pre_trained_model = Model(inputs=model.input, output=x)
    pre_trained_model.summary()
    return pre_trained_model

# %%
def process_image_real_life(img_folder, dim):
    for fruit_dir_path in glob.glob(img_folder):
        #print (fruit_dir_path )
        fruit_name = fruit_dir_path.split("\\")[-1]
        #print (fruit_name)
        image = cv2.imread(fruit_dir_path, cv2.IMREAD_COLOR)
        image = cv2.resize(image, (dim, dim))
        #print(image.shape)
        real_life_img.append((image / 255.).tolist())
        real_life_labels.append(fruit_name)
#process the raw images i.e. get the file name,resize the image accoding to model, append it to image array.

# %%
def read_label():
    fruit_list = []
    for fruit_dir_path in glob.glob('fruits/*'):
        fruit_list.append(fruit_dir_path.split("/")[-1])
    return fruit_list
#read the label,  read the folder name which gives us the fruitname from trained data.

# %%
real_life_img = []
real_life_labels = []

process_image_real_life("test/*", 100)

real_life_img = np.array(real_life_img)
#converting all the images in the list into  list of numpy arrays
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4e5f96541a01> in <module>()
#       2 real_life_labels = []
#       3
# ----> 4 process_image_real_life("test/*", 100)
#       5
#       6 real_life_img = np.array(real_life_img)
#
# <ipython-input-3-642b53c74d0e> in process_image_real_life(img_folder, dim)
#       1 def process_image_real_life(img_folder, dim):
# ----> 2     for fruit_dir_path in glob.glob(img_folder):
#       3         #print (fruit_dir_path )
#       4         fruit_name = fruit_dir_path.split("\\")[-1]
#       5         #print (fruit_name)
#
# NameError: name 'glob' is not defined

# %%
fruit_label = read_label()#read_label method called
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9971002ff66f> in <module>()
# ----> 1 fruit_label = read_label()#read_label method called
#
# <ipython-input-4-8c2561d2ef48> in read_label()
#       1 def read_label():
#       2     fruit_list = []
# ----> 3     for fruit_dir_path in glob.glob('fruits/*'):
#       4         fruit_list.append(fruit_dir_path.split("/")[-1])
#       5     return fruit_list
#
# NameError: name 'glob' is not defined

# %%
 t_model = pre_trained(True, 100) # training the pretrained model with transefer learning
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-43fe057d3380> in <module>()
# ----> 1 t_model = pre_trained(True, 100) # training the pretrained model with transefer learning
#
# <ipython-input-2-8350b35173c5> in pre_trained(trainable, dim)
#       4     #   TRUE means the last five layers are trainable
#       5     #   FALSE means non of the layers are trainable
# ----> 6     model = applications.VGG16(weights="imagenet", include_top=False, input_shape=(dim, dim, 3))
#       7     if not trainable:
#       8         for layer in model.layers[:]:
#
# NameError: name 'applications' is not defined

# %%
t_model.load_weights("checkpt.h5") #loading the weights from the pre trained model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-209bd68f9475> in <module>()
# ----> 1 t_model.load_weights("checkpt.h5") #loading the weights from the pre trained model
#
# NameError: name 't_model' is not defined

# %%
for x in real_life_labels:
    print(x)    #Debugging purpose

# %%
fruit_list = []
fruit_list = read_label()

fruit_list.sort()
print(fruit_list)  # Debugging
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-14b0cad381d7> in <module>()
#       1 fruit_list = []
# ----> 2 fruit_list = read_label()
#       3
#       4 fruit_list.sort()
#       5 print(fruit_list)  # Debugging
#
# <ipython-input-4-8c2561d2ef48> in read_label()
#       1 def read_label():
#       2     fruit_list = []
# ----> 3     for fruit_dir_path in glob.glob('fruits/*'):
#       4         fruit_list.append(fruit_dir_path.split("/")[-1])
#       5     return fruit_list
#
# NameError: name 'glob' is not defined

# %%
fruit_dict  = {"apple" : 95, 'apricot': 60, 'avacado' : 250, 'banana' : 72, 'carambola' : 28, 'granadilla':17,'grape_red':3.4, 'grape_white':3.4, 'kaki':118, 'kiwi':54, 'lemon':22, 'lime':11, 'cherry':5, 'litchi':66, 'mango':64, 'nectarine':69, 'orange':62, 'papaya':120, 'pear':56.7, 'pineapple':82, 'pomegranate':83, 'strawberry':6}
#assigning values to fruit names in Dictionary

# %%
i = -1
for _str in fruit_list:
    i += 1
    fruit_list[i] = _str.split("\\")[-1]
print(fruit_list)

#Debugging
# Out:
# []

# %%
for m in range(len(real_life_img)):#iterating thrrough all the images
    checkImage = real_life_img[m:m+1]
    prediction = t_model.predict(np.array(checkImage)) #perdicting the current image with model after converting it into np array 
    #after predicting get the name of fruit based on the predicted value
    for i in range(len(prediction)):
        for j in np.where(prediction[i] == max(prediction[i])):
            idx = int(j)
            print("Predicting ",real_life_labels[m]," as " ,fruit_list[idx], "and it has a got", fruit_dict[fruit_list[idx]]," calories")
